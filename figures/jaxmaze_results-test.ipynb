# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

print("at directory:", os.getcwd())
print("changing to root directory")
os.chdir("..")
print("at directory:", os.getcwd())
# Out:
# at directory: /Users/wilka/git/research/multitask_preplay/figures
# changing to root directory
# at directory: /Users/wilka/git/research/multitask_preplay

# %%
sys.path.append("simulations")

# %%
from analysis import jaxmaze_analysis
import data_configs
import plot_configs
# Out:
# No file specified for image dict.
# Using: /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/housemaze/image_data.pkl

# %%
import data_configs
from analysis.download_dataframes import download_jaxmaze_data

print("Data will be downloaded or saved to", data_configs.RESULTS_DIRECTORY)
download_jaxmaze_data()

# %% [markdown]
# # Load data

# %%
from data_processing import process_model_data

# %debug
model_df = process_model_data.get_jaxmaze_model_data()
model_df.head()
# Out:
# No file specified for groups.
# Using: /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/housemaze/human_dyna/list_of_groups.npy
# No file specified for groups.
# Using: /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/housemaze/human_dyna/list_of_groups.npy
# Generating model data for qlearning
# Generating model data for dyna
# Generating model data for usfa
# Generating model data for preplay
# Generating model data for bfs
# Generating model data for dfs
# shape: (5, 19)
# ┌─────────┬───────────┬─────────┬─────────────┬───┬─────────────┬─────────────┬────────────┬───────┐
# │ domain  ┆ algo      ┆ user_id ┆ manipulatio ┆ … ┆ path_length ┆ task_vector ┆ task_objec ┆ reuse │
# │ ---     ┆ ---       ┆ ---     ┆ n           ┆   ┆ ---         ┆ ---         ┆ t_id       ┆ ---   │
# │ str     ┆ str       ┆ i64     ┆ ---         ┆   ┆ i64         ┆ str         ┆ ---        ┆ i64   │
# │         ┆           ┆         ┆ str         ┆   ┆             ┆             ┆ i64        ┆       │
# ╞═════════╪═══════════╪═════════╪═════════════╪═══╪═════════════╪═════════════╪════════════╪═══════╡
# │ jaxmaze ┆ qlearning ┆ 1       ┆ paths       ┆ … ┆ 89          ┆ [0 1 0 0]   ┆ 40         ┆ -1    │
# │ jaxmaze ┆ qlearning ┆ 1       ┆ paths       ┆ … ┆ 98          ┆ [0 1 0 0]   ┆ 40         ┆ -1    │
# │ jaxmaze ┆ qlearning ┆ 1       ┆ paths       ┆ … ┆ 93          ┆ [0 1 0 0]   ┆ 40         ┆ -1    │
# │ jaxmaze ┆ qlearning ┆ 1       ┆ paths       ┆ … ┆ 111         ┆ [0 1 0 0]   ┆ 40         ┆ -1    │
# │ jaxmaze ┆ qlearning ┆ 1       ┆ paths       ┆ … ┆ 91          ┆ [0 1 0 0]   ┆ 40         ┆ -1    │
# └─────────┴───────────┴─────────┴─────────────┴───┴─────────────┴─────────────┴────────────┴───────┘

# %%
from data_processing import process_user_data

user_df = process_user_data.get_jaxmaze_human_data()
user_df.filter(eval=True).head()
# Out:
# No file specified for image dict.
# Using: /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/housemaze/image_data.pkl
# GENERATING ../preplay_results_2/data/jaxmaze/final/human_data_episode_df.parquet
# LOADING ../preplay_results_2/data/jaxmaze/final/human_data_episode_df.parquet
# shape: (5, 43)
# ┌─────────┬───────┬────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬───────┐
# │ domain  ┆ algo  ┆ user_id    ┆ manipulatio ┆ … ┆ eval_shares ┆ train_succe ┆ min_train_s ┆ reuse │
# │ ---     ┆ ---   ┆ ---        ┆ n           ┆   ┆ _start_pos  ┆ ss_count    ┆ uccess      ┆ ---   │
# │ str     ┆ str   ┆ i64        ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ i64   │
# │         ┆       ┆            ┆ str         ┆   ┆ bool        ┆ f64         ┆ bool        ┆       │
# ╞═════════╪═══════╪════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═══════╡
# │ jaxmaze ┆ human ┆ 2551730852 ┆ shortcut    ┆ … ┆ true        ┆ 16.0        ┆ true        ┆ 0     │
# │ jaxmaze ┆ human ┆ 2551730852 ┆ shortcut    ┆ … ┆ true        ┆ 16.0        ┆ true        ┆ 1     │
# │ jaxmaze ┆ human ┆ 2551730852 ┆ shortcut    ┆ … ┆ true        ┆ 16.0        ┆ true        ┆ -1    │
# │ jaxmaze ┆ human ┆ 2551730852 ┆ shortcut    ┆ … ┆ true        ┆ 16.0        ┆ true        ┆ 1     │
# │ jaxmaze ┆ human ┆ 198546081  ┆ start       ┆ … ┆ false       ┆ 16.0        ┆ true        ┆ -1    │
# └─────────┴───────┴────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴───────┘

# %% [markdown]
# # Analysis

# %%
jaxmaze_analysis.path_reuse_results(
  user_df,
  model_df,
  save_dir=data_configs.JAXMAZE_RESULTS_DIR,
  tell_reuse=1,
  display_figs=True,
  save_figs=True,
  n_simulations=1000,
  verbosity=0,
  rereun_analysis=False,
  overlap_threshold=0.5,
)
# Out:
# Num initial users:  115
# Loading cached user IDs from ../preplay_results_2/cache/path_reuse_results_user_ids.pkl
# [1866371705, 3055471004, 1523262937, 3578332183, 1064468626, 670472824, 2398258611, 4236114229, 345383270, 3528569011]
# Num users after cache filter:  100
# Removed 107 global episode indices
# Removed 0 global episode indices
# /Users/wilka/git/research/multitask_preplay/analysis/analysis_utils.py:1105: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   # First aggregate by group to get their mean rate
# /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)
# Removed 107 global episode indices
# Mean reuse:  0.6238532110091743
# Filtered 107 rows with null success or reuse
# Loading cached results from ../preplay_results_2/cache/statsfile.first_log_rt_reuse_1000_0.5.pkl
# n no_reuse: 58
# n reuse: 77
# Removed 107 global episode indices
# Mean reuse:  0.6238532110091743
# Filtered 107 rows with null success or reuse
# Loading cached results from ../preplay_results_2/cache/statsfile.max_log_rt_reuse_1000_0.5.pkl
# n no_reuse: 58
# n reuse: 77

# %%
jaxmaze_analysis.shortcut_results(
  user_df, model_df, overlap_threshold=0.6, save_figs=True
)
# Out:
# Num initial users:  105
# Loading cached user IDs from ../preplay_results_2/cache/shortcut_results_user_ids.pkl
# [468645780, 2797923562, 18824410, 3761043368, 516205828, 1579131812, 2441166385, 3442943479, 2980069354, 3883807677]
# Num users after cache filter:  100
# Removed 88 global episode indices
# Removed 0 global episode indices
# /Users/wilka/git/research/multitask_preplay/analysis/analysis_utils.py:1105: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   # First aggregate by group to get their mean rate
# /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/wilka/git/research/multitask_preplay/.venv/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
jaxmaze_analysis.start_results(
  user_df,
  ylim=[-0.05, 0.2],
  save_figs=True,
  median=True,
)
# Out:
# Num initial users:  114
# Num initial users after success filter:  114
# Adding 100 users
# [572365400, 1764885867, 1796497806, 14583402, 3895365467, 2112734708, 4224768167, 897702006, 3861696108, 3754329876]
# Saved user IDs to cache: ../preplay_results_2/cache/start_results_user_ids.pkl
# Num initial users after first 100 filter:  100

# %%
jaxmaze_analysis.juncture_results(
  user_df,
  # model_df,
  # save_dir=save_dir,
  save_figs=True,
  display_figs=False,
  # figsize=(2.5, 4),
  # options=[('short', 0)],
  # show_legend=False,
  ylim=[0, 0.4],
)
# Out:
# Num initial users:  256
# Num initial users after success filter:  256
# Adding 100 users
# [3638969755, 249575967, 1711720583, 6323856, 436567343, 4039500818, 1813245517, 1737924509, 285509568, 1127059973]
# Saved user IDs to cache: ../preplay_results_2/cache/juncture_results_user_ids.pkl
# Num initial users after first 100 filter:  100
# Adding 58 users for tell_reuse=1
# Adding 42 users for tell_reuse=0
